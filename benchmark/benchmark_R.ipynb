# %%
# パッケージをロード
library(tidyverse)
library(sf)
library(pforeach) #githubinstall::githubinstall("pforeach")

# %% [markdown]
# # シェイプファイルから検索するやり方
# ベンチマークなので本来は1万回とか繰り返して実行時間の分布をみるべきですが、時間がかかるので1回だけの実行時間で見ています。
#
# また、Pythonでは全国シェイプファイルから直接検索していますがRではそれだと遅すぎるので少しでも速くするために「都道府県を検索→都道府県の中で番地検索」というアプローチにしています。

# %%
# 桁数の設定
options(digits = 15)

# %%
# 関数定義
#' @param polygon list
#' @param lon longitude
#' @param lat latitude
## 都道府県の判定
find_pref2 <- function(polygon, lon, lat){
  point <- st_point(c(lon, lat))
  for(p in pref){
    if(length(st_contains(polygon[[p]], point)[[1]])){
      return(p)
    }
  }
  return(NA)
}

## 住所(何丁目レベル)判定
#' @param sp_polygon object of class sf, sfc or sfg
#' @param pref prefecture
#' @param lon longitude
#' @param lat latitude
find_place <- function(sp_polygon, pref, lon, lat) {

  if(is.na(pref) == TRUE) {
    return(NA)
  }

  sp_pref <- sp_polygon %>%
    dplyr::mutate_if(is.factor, as.character) %>%
    filter(KEN_NAME == pref)

  which.row <- suppressMessages(sf::st_contains(sp_pref, sf::st_point(c(lon, lat)), sparse = FALSE)) %>%
    grep(TRUE, .)

  if (identical(which.row, integer(0)) == TRUE) {
    return(NA)
  } else {
    geos <- sp_pref[which.row, ]

    place_name = paste(geos$GST_NAME,
                       geos$CSS_NAME,
                       geos$MOJI,
                       sep = ",") %>%
      stringr::str_replace_all("NA", "")
    return(place_name)
  }
}

## 県と市区町村、番地を検索
##' @param polygon polygon list
##' @param sp 番地レベルshapefile
##' @param longitude 経度
##' @param latitude 緯度
find_pref_place <- function(polygon, sp2, longitude, latitude) {
  pref <- find_pref2(polygon, longitude, latitude)
  if(is.na(pref) == TRUE) {
    return(NA)
  }
  city_banchi <- find_place(sp2, pref, longitude, latitude)
  return(paste(pref, city_banchi, sep = ","))
}

# %%
# 都道府県のshapefile読み込み
load("./R/jp.RData")
japan_p <- select(jp, KEN)
pref <- unique(jp$KEN)
# 都道府県ごとにポリゴンをまとめる
pref_polygons <- tapply(japan_p$geometry,
                        japan_p$KEN, # 都道府県名でグループ化
                        st_combine)

# %%
# 市区町村レベルのshapefileの読み込み
load("./R/zenkoku.RData")

# %% [markdown]
# ## 1件のみ逆ジオコーディング

# %%
find_pref_place(pref_polygons, zenkoku, 135.728965, 35.039200)
# Out:
# [1] "京都府,京都市,北区,金閣金閣寺町"

# %%
find_pref_place(pref_polygons, zenkoku, 139.523620, 35.495978)
# Out:
# [1] "神奈川県,横浜市,旭区,上白根町"

# %%
# 実行時間
system.time(
find_pref_place(pref_polygons, zenkoku, 139.523620, 35.495978)
)
# Out:
#             user           system          elapsed
# 2.49300000000000 0.01700000000000 2.52100000000007

# %% [markdown]
# 2.5秒

# %% [markdown]
# ## 1000件の逆ジオコーディング

# %%
# データの読み込み
# 4箇所を250回繰り返しただけ
dat <- read_csv("./dat1000.csv")
dat
# Out:
# Parsed with column specification:
# cols(
#   long = col_double(),
#   lat = col_double(),
#   location = col_character(),
#   id = col_integer()
# )
# %% [markdown]
# ### 並列処理で計算
# データをコア数分に分割し処理を分ける

# %%
# 実行
res <- pforeach(row = rows(dat), .c = rbind)({
  row %>%
    mutate(place = find_pref_place(pref_polygons, zenkoku, long, lat))
})

# %%
res
# Out:
#      long       lat       location                 id
# 1    139.884678 35.626065 東京ディズニーシー        1
# 2    139.742946 35.649114 慶應義塾大学              2
# 3    135.728965 35.039200 金閣寺                    3
# 4    139.526510 35.494865 よこはま動物園ズーラシア  4
# 5    139.884678 35.626065 東京ディズニーシー        5
# 6    139.742946 35.649114 慶應義塾大学              6
# 7    135.728965 35.039200 金閣寺                    7
# 8    139.526510 35.494865 よこはま動物園ズーラシア  8
# 9    139.884678 35.626065 東京ディズニーシー        9
# 10   139.742946 35.649114 慶應義塾大学             10
# 11   135.728965 35.039200 金閣寺                   11
# 12   139.526510 35.494865 よこはま動物園ズーラシア 12
# 13   139.884678 35.626065 東京ディズニーシー       13
# 14   139.742946 35.649114 慶應義塾大学             14
# 15   135.728965 35.039200 金閣寺                   15
# 16   139.526510 35.494865 よこはま動物園ズーラシア 16
# 17   139.884678 35.626065 東京ディズニーシー       17
# 18   139.742946 35.649114 慶應義塾大学             18
# 19   135.728965 35.039200 金閣寺                   19
# 20   139.526510 35.494865 よこはま動物園ズーラシア 20
# 21   139.884678 35.626065 東京ディズニーシー       21
# 22   139.742946 35.649114 慶應義塾大学             22
# 23   135.728965 35.039200 金閣寺                   23
# 24   139.526510 35.494865 よこはま動物園ズーラシア 24
# 25   139.884678 35.626065 東京ディズニーシー       25
# 26   139.742946 35.649114 慶應義塾大学             26
# 27   135.728965 35.039200 金閣寺                   27
# 28   139.526510 35.494865 よこはま動物園ズーラシア 28
# 29   139.884678 35.626065 東京ディズニーシー       29
# 30   139.742946 35.649114 慶應義塾大学             30
# ⋮    ⋮          ⋮         ⋮                        ⋮
# 971  135.728965 35.039200 金閣寺                    971
# 972  139.526510 35.494865 よこはま動物園ズーラシア  972
# 973  139.884678 35.626065 東京ディズニーシー        973
# 974  139.742946 35.649114 慶應義塾大学              974
# 975  135.728965 35.039200 金閣寺                    975
# 976  139.526510 35.494865 よこはま動物園ズーラシア  976
# 977  139.884678 35.626065 東京ディズニーシー        977
# 978  139.742946 35.649114 慶應義塾大学              978
# 979  135.728965 35.039200 金閣寺                    979
# 980  139.526510 35.494865 よこはま動物園ズーラシア  980
# 981  139.884678 35.626065 東京ディズニーシー        981
# 982  139.742946 35.649114 慶應義塾大学              982
# 983  135.728965 35.039200 金閣寺                    983
# 984  139.526510 35.494865 よこはま動物園ズーラシア  984
# 985  139.884678 35.626065 東京ディズニーシー        985
# 986  139.742946 35.649114 慶應義塾大学              986
# 987  135.728965 35.039200 金閣寺                    987
# 988  139.526510 35.494865 よこはま動物園ズーラシア  988
# 989  139.884678 35.626065 東京ディズニーシー        989
# 990  139.742946 35.649114 慶應義塾大学              990
# 991  135.728965 35.039200 金閣寺                    991
# 992  139.526510 35.494865 よこはま動物園ズーラシア  992
# 993  139.884678 35.626065 東京ディズニーシー        993
# 994  139.742946 35.649114 慶應義塾大学              994
# 995  135.728965 35.039200 金閣寺                    995
# 996  139.526510 35.494865 よこはま動物園ズーラシア  996
# 997  139.884678 35.626065 東京ディズニーシー        997
# 998  139.742946 35.649114 慶應義塾大学              998
# 999  135.728965 35.039200 金閣寺                    999
# 1000 139.526510 35.494865 よこはま動物園ズーラシア 1000
#      place
# 1    千葉県,浦安市,,舞浜
# 2    東京都,港区,,三田２丁目
# 3    京都府,京都市,北区,金閣金閣寺町
# 4    神奈川県,横浜市,旭区,上白根町
# 5    千葉県,浦安市,,舞浜
# 6    東京都,港区,,三田２丁目
# 7    京都府,京都市,北区,金閣金閣寺町
# 8    神奈川県,横浜市,旭区,上白根町
# 9    千葉県,浦安市,,舞浜
# 10   東京都,港区,,三田２丁目
# 11   京都府,京都市,北区,金閣金閣寺町
# 12   神奈川県,横浜市,旭区,上白根町
# 13   千葉県,浦安市,,舞浜
# 14   東京都,港区,,三田２丁目
# 15   京都府,京都市,北区,金閣金閣寺町
# 16   神奈川県,横浜市,旭区,上白根町
# 17   千葉県,浦安市,,舞浜
# 18   東京都,港区,,三田２丁目
# 19   京都府,京都市,北区,金閣金閣寺町
# 20   神奈川県,横浜市,旭区,上白根町
# 21   千葉県,浦安市,,舞浜
# 22   東京都,港区,,三田２丁目
# 23   京都府,京都市,北区,金閣金閣寺町
# 24   神奈川県,横浜市,旭区,上白根町
# 25   千葉県,浦安市,,舞浜
# 26   東京都,港区,,三田２丁目
# 27   京都府,京都市,北区,金閣金閣寺町
# 28   神奈川県,横浜市,旭区,上白根町
# 29   千葉県,浦安市,,舞浜
# 30   東京都,港区,,三田２丁目
# ⋮    ⋮
# 971  京都府,京都市,北区,金閣金閣寺町
# 972  神奈川県,横浜市,旭区,上白根町
# 973  千葉県,浦安市,,舞浜
# 974  東京都,港区,,三田２丁目
# 975  京都府,京都市,北区,金閣金閣寺町
# 976  神奈川県,横浜市,旭区,上白根町
# 977  千葉県,浦安市,,舞浜
# 978  東京都,港区,,三田２丁目
# 979  京都府,京都市,北区,金閣金閣寺町
# 980  神奈川県,横浜市,旭区,上白根町
# 981  千葉県,浦安市,,舞浜
# 982  東京都,港区,,三田２丁目
# 983  京都府,京都市,北区,金閣金閣寺町
# 984  神奈川県,横浜市,旭区,上白根町
# 985  千葉県,浦安市,,舞浜
# 986  東京都,港区,,三田２丁目
# 987  京都府,京都市,北区,金閣金閣寺町
# 988  神奈川県,横浜市,旭区,上白根町
# 989  千葉県,浦安市,,舞浜
# 990  東京都,港区,,三田２丁目
# 991  京都府,京都市,北区,金閣金閣寺町
# 992  神奈川県,横浜市,旭区,上白根町
# 993  千葉県,浦安市,,舞浜
# 994  東京都,港区,,三田２丁目
# 995  京都府,京都市,北区,金閣金閣寺町
# 996  神奈川県,横浜市,旭区,上白根町
# 997  千葉県,浦安市,,舞浜
# 998  東京都,港区,,三田２丁目
# 999  京都府,京都市,北区,金閣金閣寺町
# 1000 神奈川県,横浜市,旭区,上白根町

# %%
# 列を分割
res2 <- res %>%
  separate(place, c("pref", "city", "town", "banchi"), sep = ",")
res2[res2 == ""] <- NA
res2[res2 == "NA"] <- NA
# 981  139.884678 35.626065 東京ディズニーシー        981 千葉県   浦安市 NA
# 982  139.742946 35.649114 慶應義塾大学              982 東京都   港区   NA
# 983  135.728965 35.039200 金閣寺                    983 京都府   京都市 北区
# 984  139.526510 35.494865 よこはま動物園ズーラシア  984 神奈川県 横浜市 旭区
# 985  139.884678 35.626065 東京ディズニーシー        985 千葉県   浦安市 NA
# 986  139.742946 35.649114 慶應義塾大学              986 東京都   港区   NA
# 987  135.728965 35.039200 金閣寺                    987 京都府   京都市 北区
# 988  139.526510 35.494865 よこはま動物園ズーラシア  988 神奈川県 横浜市 旭区
# 989  139.884678 35.626065 東京ディズニーシー        989 千葉県   浦安市 NA
# 990  139.742946 35.649114 慶應義塾大学              990 東京都   港区   NA
# 991  135.728965 35.039200 金閣寺                    991 京都府   京都市 北区
# 992  139.526510 35.494865 よこはま動物園ズーラシア  992 神奈川県 横浜市 旭区
# 993  139.884678 35.626065 東京ディズニーシー        993 千葉県   浦安市 NA
# 994  139.742946 35.649114 慶應義塾大学              994 東京都   港区   NA
# 995  135.728965 35.039200 金閣寺                    995 京都府   京都市 北区
# 996  139.526510 35.494865 よこはま動物園ズーラシア  996 神奈川県 横浜市 旭区
# 997  139.884678 35.626065 東京ディズニーシー        997 千葉県   浦安市 NA
# 998  139.742946 35.649114 慶應義塾大学              998 東京都   港区   NA
# 999  135.728965 35.039200 金閣寺                    999 京都府   京都市 北区
# 1000 139.526510 35.494865 よこはま動物園ズーラシア 1000 神奈川県 横浜市 旭区
#      banchi
# 1    舞浜
# 2    三田２丁目
# 3    金閣金閣寺町
# 4    上白根町
# 5    舞浜
# 6    三田２丁目
# 7    金閣金閣寺町
# 8    上白根町
# 9    舞浜
# 10   三田２丁目
# 11   金閣金閣寺町
# 12   上白根町
# 13   舞浜
# 14   三田２丁目
# 15   金閣金閣寺町
# 16   上白根町
# 17   舞浜
# 18   三田２丁目
# 19   金閣金閣寺町
# 20   上白根町
# 21   舞浜
# 22   三田２丁目
# 23   金閣金閣寺町
# 24   上白根町
# 25   舞浜
# 26   三田２丁目
# 27   金閣金閣寺町
# 28   上白根町
# 29   舞浜
# 30   三田２丁目
# ⋮    ⋮
# 971  金閣金閣寺町
# 972  上白根町
# 973  舞浜
# 974  三田２丁目
# 975  金閣金閣寺町
# 976  上白根町
# 977  舞浜
# 978  三田２丁目
# 979  金閣金閣寺町
# 980  上白根町
# 981  舞浜
# 982  三田２丁目
# 983  金閣金閣寺町
# 984  上白根町
# 985  舞浜
# 986  三田２丁目
# 987  金閣金閣寺町
# 988  上白根町
# 989  舞浜
# 990  三田２丁目
# 991  金閣金閣寺町
# 992  上白根町
# 993  舞浜
# 994  三田２丁目
# 995  金閣金閣寺町
# 996  上白根町
# 997  舞浜
# 998  三田２丁目
# 999  金閣金閣寺町
# 1000 上白根町

# %%
# 実行時間
system.time(
  res <- pforeach(row = rows(dat), .c = rbind)({
  row %>%
    mutate(place = find_pref_place(pref_polygons, zenkoku, long, lat))
})
)
# Out:
#     user   system  elapsed
# 6993.770  166.467 2104.640

# %% [markdown]
# 約35分...
